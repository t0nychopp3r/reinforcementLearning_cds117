# %% [markdown]
# ### Reinforcement Learning - Resource Manager

# %% [markdown]
# Version 1.4:
#
# - Implement static environment
#     - Gave more reward around the water resource

# %% [markdown]
# ### Imports

# %%
import gym
import numpy as np
from gym.envs.registration import register
import matplotlib.pyplot as plt

# %% [markdown]
# ### Environment

# %%
from ResourceManagerEnvironment_v1_4 import ResourceManagerEnv
from MonteCarloTreeSearch import Node, MonteCarloTreeSearch

# %%
register(
    id='Resource-Manager-v1-4',
    entry_point='ResourceManagerEnvironment_v1_4:ResourceManagerEnv',
    kwargs={
        'grid_size': 20,           #set to desired grid size
        'window_size': 300,        #set to desired window size
        'num_water_resources': 10,  #set to desired number of water resources
        'render_mode': 'rgb_array'     #set to desired render mode ('human' or 'rgb_array')
    },
    max_episode_steps=500,
)

# %%
env = gym.make('Resource-Manager-v1-4')
num_episodes = 50

#lists to store rewards and water resources
episode_rewards = []
episode_water_resources = []

#run episodes
for episode in range(num_episodes):
    observation = env.reset()
    total_reward = 0
    total_water_resource = env.initial_water

    while True:
        #using random action selection for now
        action = env.action_space.sample()
        #take a step in the environment
        observation, reward, done, truncated, info = env.step(action)

        #accumulate the total reward for the episode
        total_reward += reward

        # Optionally, render the environment
        env.render()

        if done:
            break

    # Append episode results to lists
    episode_rewards.append(total_reward)
    episode_water_resources.append(env.water_resource)

    print(f"Episode {episode + 1}, Total Reward: {total_reward}, Total Water Resource: {env.water_resource}")
# Out:
# c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\utils\passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (20, 20)
#   logger.warn(
# c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\utils\passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\utils\passive_env_checker.py:165: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Episode 1, Total Reward: 68, Total Water Resource: -0.5
# Episode 2, Total Reward: -197, Total Water Resource: -0.5
# Episode 3, Total Reward: -159, Total Water Resource: -0.5
# Episode 4, Total Reward: -214, Total Water Resource: -0.5
# Episode 5, Total Reward: 50, Total Water Resource: -0.5
# Episode 6, Total Reward: -245, Total Water Resource: -0.5
# Episode 7, Total Reward: -204, Total Water Resource: -0.5
# Episode 8, Total Reward: -167, Total Water Resource: -0.5
# Episode 9, Total Reward: -424, Total Water Resource: -0.5
# Episode 10, Total Reward: -285, Total Water Resource: -0.5
# Episode 11, Total Reward: -275, Total Water Resource: -0.5
# Episode 12, Total Reward: -419, Total Water Resource: -0.5
# Episode 13, Total Reward: -221, Total Water Resource: -0.5
# Episode 14, Total Reward: -241, Total Water Resource: -0.5
# Episode 15, Total Reward: -134, Total Water Resource: -0.5
# Episode 16, Total Reward: -245, Total Water Resource: -0.5
# Episode 17, Total Reward: 51, Total Water Resource: -0.5
# Episode 18, Total Reward: -60, Total Water Resource: -0.5
# Episode 19, Total Reward: -17, Total Water Resource: -0.5
# Episode 20, Total Reward: -163, Total Water Resource: -0.5
# Episode 21, Total Reward: 63, Total Water Resource: -0.5
# Episode 22, Total Reward: -4, Total Water Resource: -0.5
# Episode 23, Total Reward: -110, Total Water Resource: -0.5
# Episode 24, Total Reward: -299, Total Water Resource: -0.5
# Episode 25, Total Reward: -110, Total Water Resource: -0.5
# Episode 26, Total Reward: 50, Total Water Resource: -0.5
# Episode 27, Total Reward: -100, Total Water Resource: -0.5
# Episode 28, Total Reward: -246, Total Water Resource: -0.5
# Episode 29, Total Reward: -42, Total Water Resource: 9.5
# Episode 30, Total Reward: 14, Total Water Resource: -0.5
# Episode 31, Total Reward: -199, Total Water Resource: 0.0
# Episode 32, Total Reward: -183, Total Water Resource: -0.5
# Episode 33, Total Reward: -191, Total Water Resource: -0.5
# Episode 34, Total Reward: -228, Total Water Resource: -0.5
# Episode 35, Total Reward: 14, Total Water Resource: -0.5
# Episode 36, Total Reward: -239, Total Water Resource: -0.5
# Episode 37, Total Reward: -132, Total Water Resource: -0.5
# Episode 38, Total Reward: -174, Total Water Resource: -0.5
# Episode 39, Total Reward: -372, Total Water Resource: 0.0
# Episode 40, Total Reward: 43, Total Water Resource: -0.5
# Episode 41, Total Reward: 73, Total Water Resource: -0.5
# Episode 42, Total Reward: 16, Total Water Resource: -0.5
# Episode 43, Total Reward: -192, Total Water Resource: -0.5
# Episode 44, Total Reward: -109, Total Water Resource: -0.5
# Episode 45, Total Reward: -216, Total Water Resource: -0.5
# Episode 46, Total Reward: -316, Total Water Resource: -0.5
# Episode 47, Total Reward: -313, Total Water Resource: -0.5
# Episode 48, Total Reward: -417, Total Water Resource: -0.5
# Episode 49, Total Reward: -237, Total Water Resource: -0.5
# Episode 50, Total Reward: -18, Total Water Resource: -0.5

# %%
#Plot the total rewards
plt.figure(figsize=(20,5))
plt.plot(episode_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Learning Progress')
#plot tendency curve
plt.plot(np.convolve(episode_rewards, np.ones((10,))/10, mode='valid'))
#plot average
plt.plot(np.ones(len(episode_rewards))*np.mean(episode_rewards))
plt.plot(episode_water_resources)
plt.legend(['Episode Reward', 'Tendency', 'Average', 'Water'])
plt.show()

# %% [markdown]
# ## Monte Carlo Tree Search

# %% [markdown]
# Definitionen:
#
# Iterations:
# Anzahl, wie oft die Simulation durchlaufen werden soll
#
# Simulation Steps:
# Anzahl, wie oft der Algorithmus gemacht werden soll
#
# Episoden:
# Anzahl, wie oft der komplette Suchalgorithmus mit MCTS gemacht werden soll

# %%
env = gym.make('Resource-Manager-v1-4')
num_episodes = 5
mcts = MonteCarloTreeSearch(env, iterations=500, simulation_steps=10)
episode_rewards = []
episode_water_resources = []

for episode in range(num_episodes):
    #reset the environment for a new episode
    state = env.reset()
    total_reward = 0
    total_water_resource = env.initial_water

    #initialize the root node with the current state
    root = Node(state=state)

    while True:
        #perform the search and get the best action
        best_action = mcts.search()
        #perform the selected action in the environment
        new_state, reward, done, truncated, info = env.step(best_action)
        #update the root node with the new state
        total_reward += reward
        if done:
            break

    episode_rewards.append(total_reward)
    episode_water_resources.append(env.water_resource)

    print(f"Episode {episode + 1}, Total Reward: {total_reward}, Total Water Resource: {env.water_resource}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Repos\Private\SharedProjects\ReinforcementLearning_cds(117)\reinforcementLearning_cds117\ResourceManager_v1_4.ipynb Cell 12 line 1
#      <a href='vscode-notebook-cell:/c%3A/Repos/Private/SharedProjects/ReinforcementLearning_cds%28117%29/reinforcementLearning_cds117/ResourceManager_v1_4.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> root = Node(state=state)
#      <a href='vscode-notebook-cell:/c%3A/Repos/Private/SharedProjects/ReinforcementLearning_cds%28117%29/reinforcementLearning_cds117/ResourceManager_v1_4.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Repos/Private/SharedProjects/ReinforcementLearning_cds%28117%29/reinforcementLearning_cds117/ResourceManager_v1_4.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a>     #perform the search and get the best action
# ---> <a href='vscode-notebook-cell:/c%3A/Repos/Private/SharedProjects/ReinforcementLearning_cds%28117%29/reinforcementLearning_cds117/ResourceManager_v1_4.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a>     best_action = mcts.search()
#      <a href='vscode-notebook-cell:/c%3A/Repos/Private/SharedProjects/ReinforcementLearning_cds%28117%29/reinforcementLearning_cds117/ResourceManager_v1_4.ipynb#X14sZmlsZQ%3D%3D?line=18'>19</a>     #perform the selected action in the environment
#      <a href='vscode-notebook-cell:/c%3A/Repos/Private/SharedProjects/ReinforcementLearning_cds%28117%29/reinforcementLearning_cds117/ResourceManager_v1_4.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a>     new_state, reward, done, truncated, info = env.step(best_action)
#
# File c:\Repos\Private\SharedProjects\ReinforcementLearning_cds(117)\reinforcementLearning_cds117\MonteCarloTreeSearch.py:113, in MonteCarloTreeSearch.search(self, action)
#     111 selected_node = self.select(self.root)
#     112 new_node = self.expand(selected_node)
# --> 113 simulation_result = self.simulate(new_node)
#     114 #state, reward, done = self.env.step(action)  # Ignore info during expansion
#     115 #new_state = self.env.get_obs()  # Assuming get_obs provides the new state
#     116 #new_node = Node(state=new_state, parent=selected_node, action=action)
#     117 self.backpropagate(new_node, simulation_result)
#
# File c:\Repos\Private\SharedProjects\ReinforcementLearning_cds(117)\reinforcementLearning_cds117\MonteCarloTreeSearch.py:85, in MonteCarloTreeSearch.simulate(self, node)
#      81 action = self.env.action_space.sample()
#      82 #needed for troubleshooting
#      83 #result = self.env.step(action)
#      84 #print(result)
# ---> 85 state, reward, terminated, truncated, info = self.env.step(action)
#      86 total_reward += reward
#      87 if terminated:
#
# File c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\wrappers\time_limit.py:50, in TimeLimit.step(self, action)
#      39 def step(self, action):
#      40     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      41
#      42     Args:
#    (...)
#      48
#      49     """
# ---> 50     observation, reward, terminated, truncated, info = self.env.step(action)
#      51     self._elapsed_steps += 1
#      53     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\wrappers\order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File c:\Users\denni\.conda\envs\tf\lib\site-packages\gym\wrappers\env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File c:\Repos\Private\SharedProjects\ReinforcementLearning_cds(117)\reinforcementLearning_cds117\ResourceManagerEnvironment_v1_4.py:198, in ResourceManagerEnv.step(self, action)
#     195     terminated = True
#     196     #self.reset()
# --> 198 state = self.get_obs()
#     199 info = self.get_info()
#     201 if self.render_mode == "human":
#
# File c:\Repos\Private\SharedProjects\ReinforcementLearning_cds(117)\reinforcementLearning_cds117\ResourceManagerEnvironment_v1_4.py:90, in ResourceManagerEnv.get_obs(self)
#      88 def get_obs(self):
#      89     #Initialize observation
# ---> 90     observation = np.zeros((self.grid_size, self.grid_size), dtype=np.float32)
#      92     #Mark the agent's position
#      93     observation[tuple(self.agent_position)] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluation

# %%
#Plot the total rewards
plt.figure(figsize=(20,5))
plt.plot(episode_rewards)
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Learning Progress')
#plot tendency curve
plt.plot(np.convolve(episode_rewards, np.ones((10,))/10, mode='valid'))
#plot average
plt.plot(np.ones(len(episode_rewards))*np.mean(episode_rewards))
plt.plot(episode_water_resources)
plt.legend(['Episode Reward', 'Tendency', 'Average', 'Water'])
plt.show()
